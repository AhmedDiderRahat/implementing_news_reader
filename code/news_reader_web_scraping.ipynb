# %% [markdown]
# ## Project Tilte: Implement news paper scraper and create ML pipeline

# %% [markdown]
# ### Part 1: Web scaping

# %%
import pandas as pd
import glob
import os
import itertools
import requests
import os.path as path
import numpy as np
import re

from functools import reduce
from bs4 import BeautifulSoup
from datetime import datetime

# %%
if path.exists('../input_data/news_paper_data.csv'):
    df = pd.read_csv('../input_data/news_paper_data.csv')
else:
    columns = ['node_id','title', 'date', 'url','category', 'article']
    df = pd.DataFrame(columns=columns)

# %%
df.head()
# Out:
#    node_id                                              title        date  \
# 0  3074331  Consumer rights body’s oil price monitoring st...  19-07-2022
# 1  3074126            Chattogram shares bleed for another day  19-07-2022
# 2  3073706      bKash’s instant add money service at Dev Bank  19-07-2022
# 3  3074291  Textile millers demand 360 days for deferred L...  19-07-2022
# 4  3074276  Tk 25,000 crore refinance scheme unveiled for ...  19-07-2022
#
#                                                  url  category  \
# 0  /business/news/consumer-rights-bodys-oil-price...  business
# 1  /business/news/chattogram-shares-bleed-another...  business
# 2  /business/organisation-news/news/bkashs-instan...  business
# 3  /business/news/textile-millers-demand-360-days...  business
# 4  /business/news/tk-25000-crore-refinance-scheme...  business
#
#                                              article
# 0  The Directorate of National Consumer Rights Pr...
# 1  Shares on the Chittagong Stock Exchange (CSE) ...
# 2  Clients of Bangladesh Development Bank (BDB) c...
# 3  The leaders of Bangladesh Textile Mills Associ...
# 4  Bangladesh Bank today unveiled a Tk 25,000 cro...

# %%
print(f'Check previous data: {len(df)}')
# Out:
# Check previous data: 245

# %%
# base url of the news paper
base_url = 'https://www.thedailystar.net'

# all important categories
categories = ['business', 'sports', 'entertainment']

# counts new entry using this run
new_count = 0

for category in categories:
    
    #print(base_url+category)
    page = requests.get(base_url+'/'+category)
    
    soup = BeautifulSoup(page.content, 'html.parser')
    
    # to analyze the newspaper I got all the headline of intended categories are under h2 or h3 tag
    temp_h2 = soup.find_all('h2')
    temp_h3 = soup.find_all('h3')

    all_url = temp_h2 + temp_h3

    for data in all_url:
        temp_d = data.find('a')

        url = str(temp_d.get('href'))
        title = temp_d.get_text()

        # check its on the category or not
        url_arr = url.split('/')

        url_arr = [d for d in url_arr if len(d.strip())>0]

        if category in url_arr[0]:

            # check url has a node id or not
            last_part = str(url_arr[len(url_arr)-1])

            if '-' in last_part:
                lp_arr = last_part.split('-')
                node_id = str(lp_arr[len(lp_arr)-1])

                if node_id.isnumeric():
                    if node_id not in set(df.node_id):
                        new_count += 1
                        df = df.append({'node_id': node_id, 'title': title, 'url': url, 'category': category}, 
                                       ignore_index=True)

            # is else part we can get the sub-categories
df.head()
# Out:
#    node_id                                              title        date  \
# 0  3074331  Consumer rights body’s oil price monitoring st...  19-07-2022
# 1  3074126            Chattogram shares bleed for another day  19-07-2022
# 2  3073706      bKash’s instant add money service at Dev Bank  19-07-2022
# 3  3074291  Textile millers demand 360 days for deferred L...  19-07-2022
# 4  3074276  Tk 25,000 crore refinance scheme unveiled for ...  19-07-2022
#
#                                                  url  category  \
# 0  /business/news/consumer-rights-bodys-oil-price...  business
# 1  /business/news/chattogram-shares-bleed-another...  business
# 2  /business/organisation-news/news/bkashs-instan...  business
# 3  /business/news/textile-millers-demand-360-days...  business
# 4  /business/news/tk-25000-crore-refinance-scheme...  business
#
#                                              article
# 0  The Directorate of National Consumer Rights Pr...
# 1  Shares on the Chittagong Stock Exchange (CSE) ...
# 2  Clients of Bangladesh Development Bank (BDB) c...
# 3  The leaders of Bangladesh Textile Mills Associ...
# 4  Bangladesh Bank today unveiled a Tk 25,000 cro...

# %%
print(f'Total Number of data points are: {len(df)}')
print(f'New data point added: {new_count}')
# Out:
# Total Number of data points are: 325
# New data point added: 80

# %%
df.tail()
# Out:
#      node_id                                              title date  \
# 320  3075121  National dance-drama festival begins at BSA today  NaN
# 321  3075111  The Colors of Youth: celebrating art across co...  NaN
# 322  3074206      Portraying the bucolic beauty of Bangladesh    NaN
# 323  3074006     Prachyanat to stage ‘Dumurkheko Manush’ today   NaN
# 324  3066871   ‘Beckoning Horizon’: Azmeer Hossain’s exhibit...  NaN
#
#                                                    url       category article
# 320  /entertainment/theatre-arts/news/national-danc...  entertainment     NaN
# 321  /entertainment/theatre-arts/news/the-colors-yo...  entertainment     NaN
# 322  /entertainment/theatre-arts/news/portraying-th...  entertainment     NaN
# 323  /entertainment/theatre-arts/news/prachyanat-st...  entertainment     NaN
# 324  /entertainment/theatre-arts/news/beckoning-hor...  entertainment     NaN

# %%
def article_parser(soup, node_id):
    
    article_context = soup.find(id="node-"+node_id)

    article = ''
    only_date = ''

    try:
        dt_context = article_context.find("div", {"class": "date text-10"}).get_text()
        dt_input_arr = str(dt_context).split('Last update on:')
        dt_input = str(dt_input_arr[1]).strip().replace(',', '')

        dt_arr = dt_input.split(' ')
        only_date = dt_arr[1] + '-' + dt_arr[2] + '-' + dt_arr[3]

        only_date = datetime.strptime(only_date, '%b-%d-%Y').strftime('%d-%m-%Y')
        
    except Exception as ex:
        print(f'Error: {str(ex)}')

    for paragraph in article_context.find_all('p'):
        text = paragraph.get_text()
        
        if len(text) > 0:
            article = article + ' ' + text
    
    return only_date, article.strip()

# %%
def process_log(_counter, _slice, _total, _additional_msg = ""):
    
    per_count = list(range(1, _total, int(_total/_slice)))
    
    if _additional_msg != "":
        print(_additional_msg)
    
    percentage = round(((_counter / _total) * 100), 2)
    
    msg = ''
    
    if _counter in per_count:
        msg = str(f'Complete {percentage} % of running ... ... ...')
    if _counter == _total-1:
        msg = str(f'Complete 100 % of running ... ... ...')
    
    return msg

# %%
date_list = []
article_list = []

_counter = 0
for index, row in df.iterrows():
    node_id = row['node_id']
    
    if row['article'] in (None, '', np.NaN, np.nan):
        
        #hit to get a particular article
        new_page = requests.get(base_url+row['url'])
        
        # get the content of the article
        current_soup = BeautifulSoup(new_page.content, 'html.parser')

        results = article_parser(current_soup, node_id)
        
        df.at[index, 'date'] = results[0]
        df.at[index, 'article'] = results[1]
        
        # log print
        _counter += 1
        log = process_log(_counter, 19, new_count)
        if log != '':
            print(log)
# Out:
# Complete 1.25 % of running ... ... ...
# Complete 6.25 % of running ... ... ...
# Complete 11.25 % of running ... ... ...
# Complete 16.25 % of running ... ... ...
# Complete 21.25 % of running ... ... ...
# Complete 26.25 % of running ... ... ...
# Complete 31.25 % of running ... ... ...
# Complete 36.25 % of running ... ... ...
# Complete 41.25 % of running ... ... ...
# Complete 46.25 % of running ... ... ...
# Complete 51.25 % of running ... ... ...
# Complete 56.25 % of running ... ... ...
# Complete 61.25 % of running ... ... ...
# Complete 66.25 % of running ... ... ...
# Complete 71.25 % of running ... ... ...
# Complete 76.25 % of running ... ... ...
# Complete 81.25 % of running ... ... ...
# Complete 86.25 % of running ... ... ...
# Complete 91.25 % of running ... ... ...
# Complete 96.25 % of running ... ... ...
# Complete 100 % of running ... ... ...

# %%
df.head()
# Out:
#    node_id                                              title        date  \
# 0  3074331  Consumer rights body’s oil price monitoring st...  19-07-2022
# 1  3074126            Chattogram shares bleed for another day  19-07-2022
# 2  3073706      bKash’s instant add money service at Dev Bank  19-07-2022
# 3  3074291  Textile millers demand 360 days for deferred L...  19-07-2022
# 4  3074276  Tk 25,000 crore refinance scheme unveiled for ...  19-07-2022
#
#                                                  url  category  \
# 0  /business/news/consumer-rights-bodys-oil-price...  business
# 1  /business/news/chattogram-shares-bleed-another...  business
# 2  /business/organisation-news/news/bkashs-instan...  business
# 3  /business/news/textile-millers-demand-360-days...  business
# 4  /business/news/tk-25000-crore-refinance-scheme...  business
#
#                                              article
# 0  The Directorate of National Consumer Rights Pr...
# 1  Shares on the Chittagong Stock Exchange (CSE) ...
# 2  Clients of Bangladesh Development Bank (BDB) c...
# 3  The leaders of Bangladesh Textile Mills Associ...
# 4  Bangladesh Bank today unveiled a Tk 25,000 cro...

# %%
df.tail()
# Out:
#      node_id                                              title        date  \
# 320  3075121  National dance-drama festival begins at BSA today  20-07-2022
# 321  3075111  The Colors of Youth: celebrating art across co...  20-07-2022
# 322  3074206      Portraying the bucolic beauty of Bangladesh    21-07-2022
# 323  3074006     Prachyanat to stage ‘Dumurkheko Manush’ today   19-07-2022
# 324  3066871   ‘Beckoning Horizon’: Azmeer Hossain’s exhibit...  08-07-2022
#
#                                                    url       category  \
# 320  /entertainment/theatre-arts/news/national-danc...  entertainment
# 321  /entertainment/theatre-arts/news/the-colors-yo...  entertainment
# 322  /entertainment/theatre-arts/news/portraying-th...  entertainment
# 323  /entertainment/theatre-arts/news/prachyanat-st...  entertainment
# 324  /entertainment/theatre-arts/news/beckoning-hor...  entertainment
#
#                                                article
# 320  A three-day-long national dance-drama festival...
# 321  "The Colors of Youth", an exhibition run by Ab...
# 322  Renowned artist Samar Majumder's third solo ex...
# 323  The certificate distribution ceremony for the ...
# 324  Azmeer Hossain's fifth solo exhibition "Beckon...

# %%
df.to_csv('../input_data/news_paper_data.csv', index=False)
